# %%
# import libraries
from sgd import *

# %%
# %%time
# run gradient descent with pegasos
sgd('MNIST-13.csv', [0.0005, 0.01, 0.1, 0.5, 1], 5, pegasos)
# Out:
# The average and standard deviation of run time are:
#      kval     runtime
#                  mean         std
# 0    0.05  178.474266    9.248923
# 1    1.00  184.172725    8.305287
# 2   10.00  214.394600   14.337779
# 3   50.00  513.971750   43.983870
# 4  100.00  775.527302  198.997005
# The primal objective over iterations for each k and each run:
# CPU times: user 9h 16min 26s, sys: 25min 48s, total: 9h 42min 14s
# Wall time: 2h 35min 41s
# ()
