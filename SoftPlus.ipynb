# %%
# import libraries
from sgd import *

# %%
# %%time
# run gradient descent on softplus
sgd('MNIST-13.csv', [0.0005, 0.01, 0.1, 0.5, 1], 5, softplus)
# Out:
# The average and standard deviation of run time are:
#      kval     runtime
#                  mean        std
# 0    0.05   99.357646   4.943623
# 1    1.00   99.750788   4.427596
# 2   10.00  150.151379   1.502075
# 3   50.00  480.936731  20.886353
# 4  100.00  995.023683  12.215643
# The primal objective over iterations for each k and each run:
# CPU times: user 8h 56min 9s, sys: 36min 23s, total: 9h 32min 33s
# Wall time: 2h 32min 12s
# ()
