# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
from dualSVM import dualSVM

# %%
# %%time
dualSVM('MNIST-13.csv', [0.01, 0.1, 1, 10, 100], 10)
# Out:
# ----------- Number of Support Vectors -----------
#   train_test    cval support_vector
#                                mean       std
# 0      train    0.01          159.2  5.473167
# 1      train    0.10          139.3  6.717308
# 2      train    1.00          136.5  6.900081
# 3      train   10.00          136.3  6.848357
# 4      train  100.00          136.2  6.746192
# --------------------- Accuracy ---------------------
#   train_test    cval  accuracy
#                           mean       std
# 0       test    0.01  96.65000  0.826640
# 1       test    0.10  96.57500  0.791008
# 2       test    1.00  96.60000  0.792324
# 3       test   10.00  96.60000  0.792324
# 4       test  100.00  96.60000  0.792324
# 5      train    0.01  96.71875  0.257273
# 6      train    0.10  96.70625  0.265247
# 7      train    1.00  96.71250  0.248607
# 8      train   10.00  96.71250  0.248607
# 9      train  100.00  96.71250  0.248607
# ----------- Number of Misclassifications -----------
# ...
